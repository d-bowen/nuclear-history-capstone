# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import FloatImage
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import time
import numpy as np

# %%
reactors = pd.read_csv('../data/Cleaned Data - Copy/all_reactors_refilled.csv')
reactors.head()
# Out:
#         Status Country ReactorCode         Reactor Name  Type Grid Connection  \
# 0  Operational  France       FR-17      ST. LAURENT B-1   PWR        1/1/1981
# 1  Operational  France       FR-23      ST. LAURENT B-2   PWR        6/1/1981
# 2    Shut Down   Italy        IT-3         ENRICO FERMI   PWR       10/1/1964
# 3    Shut Down   Japan        JP-5  FUKUSHIMA-DAIICHI-1   BWR       11/1/1970
# 4    Shut Down   Japan        JP-9  FUKUSHIMA-DAIICHI-2   BWR       12/1/1973
#
#            Online Commercial operation  Shutdown  \
# 0   January, 1981             8/1/1983       NaN
# 1      June, 1981             8/1/1983       NaN
# 2   October, 1964             1/1/1965  7/1/1990
# 3  November, 1970             3/1/1971  5/1/2011
# 4  December, 1973             7/1/1974  5/1/2011
#
#                         Offline   Latitude   Longitude  \
# 0  None (Currently operational)  47.720000    1.577500
# 1  None (Currently operational)  47.720000    1.577500
# 2                    July, 1990  45.184094    8.277556
# 3                     May, 2011  37.423060  141.033060
# 4                     May, 2011  37.423060  141.033060
#
#                                                Link1  \
# 0  https://en.wikipedia.org/wiki/Saint-Laurent_Nu...
# 1  https://en.wikipedia.org/wiki/Saint-Laurent_Nu...
# 2         https://en.wikipedia.org/wiki/Enrico_Fermi
# 3  https://en.wikipedia.org/wiki/Fukushima_Daiich...
# 4  https://en.wikipedia.org/wiki/Fukushima_Daiich...
#
#                                                Link2  \
# 0  http://www.world-nuclear.org/reactor/default.a...
# 1  http://www.world-nuclear.org/reactor/default.a...
# 2  https://en.wikipedia.org/wiki/Enrico_Fermi_Nuc...
# 3  https://en.wikipedia.org/wiki/Fukushima_Daiich...
# 4  https://en.wikipedia.org/wiki/Fukushima_Daiich...
#
#                                                Link3  Power from Nuclear
# 0                                                NaN                0.71
# 1                                                NaN                0.71
# 2                                                NaN                0.00
# 3  https://www.world-nuclear.org/information-libr...                0.03
# 4  https://www.world-nuclear.org/information-libr...                0.03

# %%
conditions = [
    reactors['Status'] == 'Shut Down',
    reactors['Status'] == 'Operational'
    ]

values = ['lightgray', 'darkblue']

reactors['color'] = np.select(conditions, values)

# %%
geometry = [Point(xy) for xy in zip(reactors.Longitude, reactors.Latitude)]
reactor_geo = gpd.GeoDataFrame(reactors, crs="EPSG:3857", geometry=geometry)

# %%
reactor_map = folium.Map(location = [0, 0], zoom_start = 1)
folium.TileLayer('cartodbpositron').add_to(reactor_map)

# %%
marker_cluster = MarkerCluster().add_to(reactor_map)

for row_index, row_values in reactor_geo.iterrows():
    loc = [row_values['Latitude'], row_values['Longitude']]
    pop = row_values['Reactor Name']
    marker = folium.Marker(
        location = loc,
        icon = folium.Icon(color=row_values['color'],icon="bolt", prefix='fa'),
#        radius=100,
        popup = pop,
        fill=True,
        color=row_values['color']) 
    
    marker.add_to(marker_cluster)
    
#    marker.add_to(ntest_map)
    
reactor_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
reactor_map2 = folium.Map(location = [0, 0], zoom_start = 1)
folium.TileLayer('cartodbpositron').add_to(reactor_map2)

# %%
marker_cluster = MarkerCluster().add_to(reactor_map2)

for row_index, row_values in reactor_geo.iterrows():
    name = row_values['Reactor Name']
    state = row_values['Country']
    date_online = 'Connected to grid: ' + row_values['Online']
    date_offline = 'Date of shutdown: ' + row_values['Offline']
    link1 = row_values['Link1']
    link2 = row_values['Link2']
    hue = row_values['color']
    html="""
        <h2>{reactor}</h2>
        <h3>{country}</h3><br>
        {on}<br>
        {off}<br>
        <p>
        Further reading:<br>
        <a href="{external1}">Link 1</a><br>
        <a href="{external2}">Link 2</a><br>
        </p>
        """
    html = html.format(reactor=name, country=state, external1 = link1, 
                       on=date_online, off=date_offline, external2 = link2)
    iframe = folium.IFrame(html=html, width=300, height=300)
    pop = folium.Popup(iframe, max_width=2650)
    loc = [row_values['Latitude'], row_values['Longitude']]
    marker = folium.Marker(
        location = loc,
        icon = folium.Icon(color=hue,icon="bolt", prefix='fa'),
#        radius=100,
        popup = pop,
        fill=True,
        color=hue)
    
    marker.add_to(marker_cluster)
    
#    marker.add_to(ntest_map)

url = ('https://raw.githubusercontent.com/d-bowen/d-bowen.github.io/main/media/reactors_legend.PNG')
folium.plugins.FloatImage(url, bottom=85, left=75).add_to(reactor_map2)
    
reactor_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
reactor_map2.save('../maps/reactor_map.html')
