# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import FloatImage
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import time
import numpy as np

# %%
ntests = pd.read_csv('../data/Cleaned data/nuclear_test_coordinates.csv')
ntests.head()
# Out:
#   STATE TESTTYPE  ID# SERIES SHOT       Date  YEAR MONTH  DAY  TIME  ...  MAG  \
# 0    CH  Nuclear    1    NaN  596  16-Oct-64  1964   OCT   16  7:00  ...  NaN
# 1    CH  Nuclear    2    NaN  NaN  14-May-65  1965   MAY   14  2:00  ...  NaN
# 2    CH  Nuclear    3    NaN  NaN   9-May-66  1966   MAY    9  8:00  ...  NaN
# 3    CH  Nuclear    4    NaN  NaN  27-Oct-66  1966   OCT   27  1:10  ...  NaN
# 4    CH  Nuclear    5    NaN  NaN  28-Dec-66  1966   DEC   28  4:00  ...  NaN
#
#    CRATER (M)  VENT DEVICE  WARHEAD SPONSOR  R    N  SOURCES LINKS
# 0         NaN   NaN     IU      NGB     NaN  C  NaN  1, 2, 3   NaN
# 1         NaN   NaN     IU      NGB     NaN  C    *  1, 2, 3   NaN
# 2         NaN   NaN     BF      NaN     NaN  C    *  1, 2, 3   NaN
# 3         NaN   NaN     IU  DF-2 wh     NaN  C    *  1, 2, 3   NaN
# 4         NaN   NaN     BF      NaN     NaN  C  NaN  1, 2, 3   NaN
#
# [5 rows x 35 columns]

# %%
geometry = [Point(xy) for xy in zip(ntests.LONG, ntests.LAT)]
ntest_geo = gpd.GeoDataFrame(ntests, crs="EPSG:4326", geometry=geometry)

# %%
ntest_map = folium.Map(location = [0, 0], zoom_start = 1)
folium.TileLayer('cartodbpositron').add_to(ntest_map)

# %%
marker_cluster = MarkerCluster().add_to(ntest_map)

for row_index, row_values in ntest_geo.iterrows():
    loc = [row_values['LAT'], row_values['LONG']]
    pop = 'Country: ' + row_values['STATE'] +'\n' + 
        'Testotesto'
    marker = folium.Marker(
        location = loc,
        icon = folium.Icon(color="red",icon="bullseye", prefix='fa'),
#        radius=100,
        popup = pop,
        fill=True,
        color='red') 
    
    marker.add_to(marker_cluster)
    
#    marker.add_to(ntest_map)
    
ntest_map
# Out:
#   File "<ipython-input-26-61ad3e67c66a>", line 5
#     pop = 'Country: ' + row_values['STATE'] +'\n' +
#                                                     ^
# SyntaxError: invalid syntax
