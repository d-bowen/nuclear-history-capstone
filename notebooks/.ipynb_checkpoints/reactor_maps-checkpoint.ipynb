# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import FloatImage
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import time
import numpy as np

# %%
reactors = pd.read_csv('../data/Cleaned data/operational_reactor_coordinates.csv')
reactors.head()
# Out:
#           Type      Country Reactor Code   Reactor Name Type.1  \
# 0  Operational          USA      US -346  DAVIS BESSE-1    PWR
# 1  Operational        SPAIN        ES -8         ASCO-1    PWR
# 2  Operational        SPAIN        ES -9         ASCO-2    PWR
# 3  Operational        SPAIN       ES -16    VANDELLOS-2    PWR
# 4  Operational  SWITZERLAND        CH -4        GOESGEN    PWR
#
#             Model  Capacity (MW)-Thermal  Capacity (MW)-Gross  \
# 0  B&W RLP (DRYAM                   2817                  925
# 1          WH 3LP                   2954                 1033
# 2          WH 3LP                   2941                 1035
# 3          WH 3LP                   2941                 1087
# 4      PWR 3 Loop                   3002                 1060
#
#    Capacity (MW)-Net Operator NSSS\nsupplier Construction\nstart  \
# 0                894    FENOC            B&W              1970-9
# 1                995     ANAV             WH              1974-5
# 2                997     ANAV             WH              1975-3
# 3               1045     ANAV             WH             1980-12
# 4               1010      KKG            KWU             1973-12
#
#   Grid\nconnection Commercial\noperation      EAF %      UCF % Non-  \
# 0           1977-8                1978-7  88.143336  88.143336    -
# 1           1983-8               1984-12  88.510019  89.396514    -
# 2          1985-10                1986-3  87.122131  88.461502    -
# 3          1987-12                1988-3  83.475425  84.729610    -
# 4           1979-2               1979-11  89.696076  90.270695   PH
#
#     Latitude  Longitude
# 0  41.596667 -83.086389
# 1  41.200000   0.569444
# 2  41.200000   0.569444
# 3  40.951389   0.866667
# 4  47.366111   7.966667

# %%
geometry = [Point(xy) for xy in zip(reactors.Longitude, reactors.Latitude)]
reactor_geo = gpd.GeoDataFrame(reactors, crs="EPSG:3857", geometry=geometry)

# %%
reactor_map = folium.Map(location = [0, 0], zoom_start = 1)
folium.TileLayer('cartodbpositron').add_to(reactor_map)

# %%
marker_cluster = MarkerCluster().add_to(reactor_map)

for row_index, row_values in reactor_geo.iterrows():
    loc = [row_values['Latitude'], row_values['Longitude']]
    pop = row_values['Reactor Name']
    marker = folium.Marker(
        location = loc,
        icon = folium.Icon(color="red",icon="bullseye", prefix='fa'),
#        radius=100,
        popup = pop,
        fill=True,
        color='red') 
    
    marker.add_to(marker_cluster)
    
#    marker.add_to(ntest_map)
    
reactor_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
